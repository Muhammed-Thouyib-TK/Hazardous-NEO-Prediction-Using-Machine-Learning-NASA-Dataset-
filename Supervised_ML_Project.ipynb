# %%
# importing libraries

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the dataset
pd.set_option('display.float_format', '{:.2f}'.format)

df = pd.read_csv('nearest-earth-objects(1910-2024).csv')
df
# Out:
#           neo_id                name  absolute_magnitude  \
# 0        2162117  162117 (1998 SD15)               19.14
# 1        2349507    349507 (2008 QY)               18.50
# 2        2455415    455415 (2003 GA)               21.45
# 3        3132126           (2002 PB)               20.63
# 4        3557844           (2011 DW)               22.70
# ...          ...                 ...                 ...
# 338194  54403809          (2023 VS4)               28.58
# 338195  54415298          (2023 XW5)               28.69
# 338196  54454871          (2024 KJ7)               21.92
# 338197  54456245           (2024 NE)               23.89
# 338198  54460573          (2024 NH3)               22.95
#
#         estimated_diameter_min  estimated_diameter_max orbiting_body  \
# 0                         0.39                    0.88         Earth
# 1                         0.53                    1.19         Earth
# 2                         0.14                    0.30         Earth
# ...

# %%
# to get the basic info about the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338199 entries, 0 to 338198
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   neo_id                  338199 non-null  int64
#  1   name                    338199 non-null  object
#  2   absolute_magnitude      338171 non-null  float64
#  3   estimated_diameter_min  338171 non-null  float64
#  4   estimated_diameter_max  338171 non-null  float64
#  5   orbiting_body           338199 non-null  object
#  6   relative_velocity       338199 non-null  float64
#  7   miss_distance           338199 non-null  float64
#  8   is_hazardous            338199 non-null  bool
# dtypes: bool(1), float64(5), int64(1), object(2)
# memory usage: 21.0+ MB

# %%
# to get the basic stats of dataset

df.describe()
# Out:
#            neo_id  absolute_magnitude  estimated_diameter_min  \
# count   338199.00           338171.00               338171.00
# mean  17599388.68               22.93                    0.16
# std   22872246.43                2.91                    0.31
# min    2000433.00                9.25                    0.00
# 25%    3373980.00               20.74                    0.03
# 50%    3742127.00               22.80                    0.07
# 75%   54053736.50               25.10                    0.19
# max   54462807.00               33.58                   37.55
#
#        estimated_diameter_max  relative_velocity  miss_distance
# count               338171.00          338199.00      338199.00
# mean                     0.35           51060.66    41535350.93
# std                      0.70           26399.24    20773990.25
# min                      0.00             203.35        6745.53
# 25%                      0.06           30712.03    24945397.53
# ...

# %%
# to get the count of elements in is_hazardous column

e_count = df.is_hazardous.value_counts()
e_count
# Out:
# is_hazardous
# False    295037
# True      43162
# Name: count, dtype: int64

# %%
# to plot it in a chart

plt.title('Hazardous Effect')
e_count.plot(kind='bar',color='#FF6666')
plt.show()

# %%
# to check for null values

df.isnull().sum()/len(df)
# Out:
# neo_id                   0.00
# name                     0.00
# absolute_magnitude       0.00
# estimated_diameter_min   0.00
# estimated_diameter_max   0.00
# orbiting_body            0.00
# relative_velocity        0.00
# miss_distance            0.00
# is_hazardous             0.00
# dtype: float64

# %%
# to drop the null values

len(df)
# Out:
# 338199

# %%
df = df.dropna()
df
# Out:
#           neo_id                name  absolute_magnitude  \
# 0        2162117  162117 (1998 SD15)               19.14
# 1        2349507    349507 (2008 QY)               18.50
# 2        2455415    455415 (2003 GA)               21.45
# 3        3132126           (2002 PB)               20.63
# 4        3557844           (2011 DW)               22.70
# ...          ...                 ...                 ...
# 338194  54403809          (2023 VS4)               28.58
# 338195  54415298          (2023 XW5)               28.69
# 338196  54454871          (2024 KJ7)               21.92
# 338197  54456245           (2024 NE)               23.89
# 338198  54460573          (2024 NH3)               22.95
#
#         estimated_diameter_min  estimated_diameter_max orbiting_body  \
# 0                         0.39                    0.88         Earth
# 1                         0.53                    1.19         Earth
# 2                         0.14                    0.30         Earth
# ...

# %%
len(df)
# Out:
# 338171

# %%
df.isnull().sum()/len(df)
# Out:
# neo_id                   0.00
# name                     0.00
# absolute_magnitude       0.00
# estimated_diameter_min   0.00
# estimated_diameter_max   0.00
# orbiting_body            0.00
# relative_velocity        0.00
# miss_distance            0.00
# is_hazardous             0.00
# dtype: float64

# %%
df.describe()
# Out:
#            neo_id  absolute_magnitude  estimated_diameter_min  \
# count   338171.00           338171.00               338171.00
# mean  17600405.46               22.93                    0.16
# std   22872761.14                2.91                    0.31
# min    2000433.00                9.25                    0.00
# 25%    3373980.00               20.74                    0.03
# 50%    3742127.00               22.80                    0.07
# 75%   54053738.50               25.10                    0.19
# max   54462807.00               33.58                   37.55
#
#        estimated_diameter_max  relative_velocity  miss_distance
# count               338171.00          338171.00      338171.00
# mean                     0.35           51060.02    41535473.46
# std                      0.70           26399.92    20774114.73
# min                      0.00             203.35        6745.53
# 25%                      0.06           30710.63    24944951.86
# ...

# %%
# to check the orbiting_body column is relevant or not

ob_count = df.orbiting_body.value_counts()
ob_count
# Out:
# orbiting_body
# Earth    338171
# Name: count, dtype: int64

# %%
ob_count.plot(kind='bar',color='skyblue')
plt.show()

# %%
# to drop the irrelevant columns

df.drop(['neo_id','name','orbiting_body'],axis=1,inplace=True)
# Out:
# C:\Users\Muhammed Thouyib TK\AppData\Local\Temp\ipykernel_26960\3480846115.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['neo_id','name','orbiting_body'],axis=1,inplace=True)

# %%
df
# Out:
#         absolute_magnitude  estimated_diameter_min  estimated_diameter_max  \
# 0                    19.14                    0.39                    0.88
# 1                    18.50                    0.53                    1.19
# 2                    21.45                    0.14                    0.30
# 3                    20.63                    0.20                    0.44
# 4                    22.70                    0.08                    0.17
# ...                    ...                     ...                     ...
# 338194               28.58                    0.01                    0.01
# 338195               28.69                    0.00                    0.01
# 338196               21.92                    0.11                    0.25
# 338197               23.89                    0.04                    0.10
# 338198               22.95                    0.07                    0.15
#
#         relative_velocity  miss_distance  is_hazardous
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 338171 entries, 0 to 338198
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   absolute_magnitude      338171 non-null  float64
#  1   estimated_diameter_min  338171 non-null  float64
#  2   estimated_diameter_max  338171 non-null  float64
#  3   relative_velocity       338171 non-null  float64
#  4   miss_distance           338171 non-null  float64
#  5   is_hazardous            338171 non-null  bool
# dtypes: bool(1), float64(5)
# memory usage: 15.8 MB

# %%
# to convert bool into integer by encoding

df['is_hazardous']=pd.get_dummies(df['is_hazardous'],dtype=int,drop_first=True)
# Out:
# C:\Users\Muhammed Thouyib TK\AppData\Local\Temp\ipykernel_26960\316309418.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_hazardous']=pd.get_dummies(df['is_hazardous'],dtype=int,drop_first=True)

# %%
df
# Out:
#         absolute_magnitude  estimated_diameter_min  estimated_diameter_max  \
# 0                    19.14                    0.39                    0.88
# 1                    18.50                    0.53                    1.19
# 2                    21.45                    0.14                    0.30
# 3                    20.63                    0.20                    0.44
# 4                    22.70                    0.08                    0.17
# ...                    ...                     ...                     ...
# 338194               28.58                    0.01                    0.01
# 338195               28.69                    0.00                    0.01
# 338196               21.92                    0.11                    0.25
# 338197               23.89                    0.04                    0.10
# 338198               22.95                    0.07                    0.15
#
#         relative_velocity  miss_distance  is_hazardous
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 338171 entries, 0 to 338198
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   absolute_magnitude      338171 non-null  float64
#  1   estimated_diameter_min  338171 non-null  float64
#  2   estimated_diameter_max  338171 non-null  float64
#  3   relative_velocity       338171 non-null  float64
#  4   miss_distance           338171 non-null  float64
#  5   is_hazardous            338171 non-null  int64
# dtypes: float64(5), int64(1)
# memory usage: 18.1 MB

# %%
# to get advanced stats 

import Dis_Stats as ds

for i in df.columns:
    print('||',i,'||')
    ds.calc_fo(df[i])
    print('='*50)
# Out:
# || absolute_magnitude ||
# Total 7755114.898
# Total Count 338171
# Mean 22.93252495926617
# Median 22.8
# Mode 24.4
# Minimum 9.25
# Maximum 33.58
# Range 24.33
# Variance 8.475155809286075
# Standard Deviation 2.9112120859336366
# Quartile 1 20.74
# Quartile 3 25.1
# Inter Quartile Range 4.360000000000003
# Lower Whisker 14.199999999999994
# Upper Whisker 31.640000000000008
# 0.08402015435845454
# -0.47558776935246216
# ...
# || estimated_diameter_min ||
# Total 53367.4576312465
# Total Count 338171
# Mean 0.15781204666055487
# Median 0.0732073989
# Mode 0.0350392641
# Minimum 0.0005111578
# Maximum 37.5452479361
# Range 37.5447367783
# Variance 0.09852358843837723
# Standard Deviation 0.3138846737870093
# Quartile 1 0.0253837029
# Quartile 3 0.1890405519
# Inter Quartile Range 0.163656849
# Lower Whisker -0.2201015706
# Upper Whisker 0.43452582539999995
# 30.963126247146
# 2664.5642097761993
# ...
# || estimated_diameter_max ||
# Total 119333.2630495297
# Total Count 338171
# ...

# %%
# to create boxplot for checking outliers 

for i in df.columns:
    print(i)
    sns.boxplot(df[i])
    plt.show()
# Out:
# absolute_magnitude
# estimated_diameter_min
# estimated_diameter_max
# relative_velocity
# miss_distance
# is_hazardous

# %%
# to create distribution plot

for i in df.drop('is_hazardous',axis=1).columns:
    print(i)
    sns.displot(data=df,x=i,hue='is_hazardous')
    plt.show()
# Out:
# absolute_magnitude
# estimated_diameter_min
# estimated_diameter_max
# relative_velocity
# miss_distance

# %%
# to create violinplot

for i in df.drop('is_hazardous',axis=1).columns:
    print(i)
    sns.violinplot(data=df,x=i,hue='is_hazardous')
    plt.show()
# Out:
# absolute_magnitude
# estimated_diameter_min
# estimated_diameter_max
# relative_velocity
# miss_distance

# %%
# to create pairplot

sns.heatmap(df.corr(),annot=True,vmin=-1,vmax=1,cmap='coolwarm')
# Out:
# <Axes: >

# %%
# the estimated_diameter_min & estimated_diameter_max are perfectly correlated , so drop any one of them

df.drop('estimated_diameter_min',axis=1,inplace=True)
# Out:
# C:\Users\Muhammed Thouyib TK\AppData\Local\Temp\ipykernel_26960\4081657976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('estimated_diameter_min',axis=1,inplace=True)

# %%
df
# Out:
#         absolute_magnitude  estimated_diameter_max  relative_velocity  \
# 0                    19.14                    0.88           71745.40
# 1                    18.50                    1.19          109949.76
# 2                    21.45                    0.30           24865.51
# 3                    20.63                    0.44           78890.08
# 4                    22.70                    0.17           56036.52
# ...                    ...                     ...                ...
# 338194               28.58                    0.01           56646.99
# 338195               28.69                    0.01           21130.77
# 338196               21.92                    0.25           11832.04
# 338197               23.89                    0.10           56198.38
# 338198               22.95                    0.15           42060.36
#
#         miss_distance  is_hazardous
# 0         58143623.32             0
# 1         55801047.82             1
# ...

# %%
# to create a function that remove outliers

def remove_outliers(data,column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - IQR*1.5
    upper = Q3 + IQR*1.5
    before = len(data)
    data = data[(data[column]>=lower) & (data[column]<=upper)]
    Updated = before - len(data)
    print('Removed rows :',Updated)

# %%
for i in df.drop('is_hazardous',axis=1).columns:
    remove_outliers(df,i)
# Out:
# Removed rows : 389
# Removed rows : 26166
# Removed rows : 5448
# Removed rows : 0

# %%
# to split the dataset

x = df.drop('is_hazardous',axis=1)
y = df['is_hazardous']

# %%
x
# Out:
#         absolute_magnitude  estimated_diameter_max  relative_velocity  \
# 0                    19.14                    0.88           71745.40
# 1                    18.50                    1.19          109949.76
# 2                    21.45                    0.30           24865.51
# 3                    20.63                    0.44           78890.08
# 4                    22.70                    0.17           56036.52
# ...                    ...                     ...                ...
# 338194               28.58                    0.01           56646.99
# 338195               28.69                    0.01           21130.77
# 338196               21.92                    0.25           11832.04
# 338197               23.89                    0.10           56198.38
# 338198               22.95                    0.15           42060.36
#
#         miss_distance
# 0         58143623.32
# 1         55801047.82
# 2         67206887.72
# 3         30396444.12
# ...

# %%
y
# Out:
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 338194    0
# 338195    0
# 338196    0
# 338197    0
# 338198    0
# Name: is_hazardous, Length: 338171, dtype: int64

# %%
# to split the data into training & testing (CV)

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#         absolute_magnitude  estimated_diameter_max  relative_velocity  \
# 108946               18.70                    1.08          128822.40
# 25572                22.75                    0.17           38706.72
# 307001               26.86                    0.03           29243.38
# 11765                22.21                    0.21           74013.39
# 207306               25.50                    0.05           38289.32
# ...                    ...                     ...                ...
# 119883               22.23                    0.21           64366.74
# 259197               27.10                    0.02           49230.95
# 131936               21.48                    0.30           22901.36
# 146872               27.50                    0.02           21820.93
# 121962               27.00                    0.02           59713.35
#
#         miss_distance
# 108946    62201948.52
# 25572     17338221.39
# 307001    48110802.42
# 11765     70850153.00
# ...

# %%
x_test
# Out:
#         absolute_magnitude  estimated_diameter_max  relative_velocity  \
# 313083               26.00                    0.04           20674.61
# 229327               26.40                    0.03           83322.24
# 147689               25.31                    0.05           16497.68
# 162245               31.46                    0.00           64667.07
# 115618               23.65                    0.11           15618.34
# ...                    ...                     ...                ...
# 323868               24.11                    0.09           23160.14
# 2952                 22.80                    0.16           49005.94
# 316310               25.30                    0.05           21254.03
# 305942               25.70                    0.04           26224.03
# 138162               18.37                    1.26           90407.77
#
#         miss_distance
# 313083     8875337.72
# 229327    57847259.56
# 147689    25840275.27
# 162245     5028880.41
# ...

# %%
y_train
# Out:
# 108946    1
# 25572     0
# 307001    0
# 11765     0
# 207306    0
#          ..
# 119883    0
# 259197    0
# 131936    1
# 146872    0
# 121962    0
# Name: is_hazardous, Length: 270536, dtype: int64

# %%
y_test
# Out:
# 313083    0
# 229327    0
# 147689    0
# 162245    0
# 115618    0
#          ..
# 323868    0
# 2952      0
# 316310    0
# 305942    0
# 138162    0
# Name: is_hazardous, Length: 67635, dtype: int64

# %%
# to check the training data is balanced

y_train.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='is_hazardous'>

# %%
# to generate some fake data based on the input data we have

from imblearn import over_sampling

# synthetic minority over-sampling technique (SMOTE)

se = over_sampling.SMOTE()

# %%
x_train_balanced,y_train_balanced = se.fit_resample(x_train,y_train)

# %%
y_train.value_counts()
# Out:
# is_hazardous
# 0    235921
# 1     34615
# Name: count, dtype: int64

# %%
y_train_balanced.value_counts()
# Out:
# is_hazardous
# 1    235921
# 0    235921
# Name: count, dtype: int64

# %%
x_train_balanced
# Out:
#         absolute_magnitude  estimated_diameter_max  relative_velocity  \
# 0                    18.70                    1.08          128822.40
# 1                    22.75                    0.17           38706.72
# 2                    26.86                    0.03           29243.38
# 3                    22.21                    0.21           74013.39
# 4                    25.50                    0.05           38289.32
# ...                    ...                     ...                ...
# 471837               19.78                    0.71           39506.75
# 471838               21.50                    0.30           56112.06
# 471839               19.33                    0.89           68670.37
# 471840               18.97                    0.96           53132.08
# 471841               18.00                    1.51           60994.32
#
#         miss_distance
# 0         62201948.52
# 1         17338221.39
# 2         48110802.42
# 3         70850153.00
# ...

# %%
x_test
# Out:
#         absolute_magnitude  estimated_diameter_max  relative_velocity  \
# 313083               26.00                    0.04           20674.61
# 229327               26.40                    0.03           83322.24
# 147689               25.31                    0.05           16497.68
# 162245               31.46                    0.00           64667.07
# 115618               23.65                    0.11           15618.34
# ...                    ...                     ...                ...
# 323868               24.11                    0.09           23160.14
# 2952                 22.80                    0.16           49005.94
# 316310               25.30                    0.05           21254.03
# 305942               25.70                    0.04           26224.03
# 138162               18.37                    1.26           90407.77
#
#         miss_distance
# 313083     8875337.72
# 229327    57847259.56
# 147689    25840275.27
# 162245     5028880.41
# ...

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

# %%
lr.fit(x_train_balanced,y_train_balanced)
# Out:
# LogisticRegression()

# %%
y_pred_test = lr.predict(x_test)
y_pred_test
# Out:
# array([0, 1, 0, ..., 0, 0, 1], shape=(67635,))

# %%
# to get the classification report

from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.72      0.81     59088
#            1       0.23      0.58      0.33      8547
#
#     accuracy                           0.70     67635
#    macro avg       0.58      0.65      0.57     67635
# weighted avg       0.83      0.70      0.75     67635

# %%
# Random Forest

from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(x_train_balanced,y_train_balanced)
# Out:
# RandomForestClassifier()

# %%
rfc_pred_test = rf.predict(x_test)

# %%
print(classification_report(y_test,rfc_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     59088
#            1       0.65      0.67      0.66      8547
#
#     accuracy                           0.91     67635
#    macro avg       0.80      0.81      0.80     67635
# weighted avg       0.91      0.91      0.91     67635

# %%
from sklearn.metrics import roc_auc_score

print("ROC-AUC Score:", roc_auc_score(y_test, rf.predict_proba(x_test)[:, 1]))
# Out:
# ROC-AUC Score: 0.9463233697342146

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 338171 entries, 0 to 338198
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   absolute_magnitude      338171 non-null  float64
#  1   estimated_diameter_max  338171 non-null  float64
#  2   relative_velocity       338171 non-null  float64
#  3   miss_distance           338171 non-null  float64
#  4   is_hazardous            338171 non-null  int64
# dtypes: float64(4), int64(1)
# memory usage: 15.5 MB

# %%
absolute_magnitude = float(input('Absolute Magnitude : '))
estimated_diameter_max = float(input('Estimated Diameter Max : '))
relative_velocity = float(input('Relative Velocity : '))
miss_distance = float(input('Miss Distance : '))

user_input = np.array([absolute_magnitude,estimated_diameter_max,relative_velocity,miss_distance]).reshape(1,-1)

if rf.predict(user_input) == 1:
    print('It is Hazardous For Earth')
else:
    print('It is Not Hazardous For Earth')
# Out:
# Absolute Magnitude :  18.50
# Estimated Diameter Max :  1.19
# Relative Velocity :  109949.76
# Miss Distance :  55801047.82
# It is Hazardous For Earth
# C:\Users\Muhammed Thouyib TK\.conda\envs\Machine_Learning\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
# model deployment

import joblib
filename = 'Hazardous_Deploy.pkl'
joblib.dump(rf, filename, compress=3)

load_model = joblib.load("Hazardous_Deploy.pkl")
