# %%
# importing libraries

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\asyncio\base_events.py", line 1987, in _run_once
#     handle._run()
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Muhammed Thouyib TK\AppData\Local\Temp\ipykernel_16612\1107872300.py", line 4, in <module>
#     import pandas as pd
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\array.py", line 50, in <module>
#     from pandas.core import (
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\core\computation\expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\core\computation\check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\numexpr\__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\asyncio\base_events.py", line 1987, in _run_once
#     handle._run()
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Muhammed Thouyib TK\AppData\Local\Temp\ipykernel_16612\1107872300.py", line 4, in <module>
#     import pandas as pd
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\__init__.py", line 62, in <module>
#     from pandas.core.api import (
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\arrow\array.py", line 64, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\core\arrays\masked.py", line 60, in <module>
#     from pandas.core import (
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\core\nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\Muhammed Thouyib TK\anaconda3\Lib\site-packages\bottleneck\__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.

# %%
# load the dataset

df = pd.read_csv('nearest-earth-objects(1910-2024).csv')
df
# Out:
#           neo_id                name  absolute_magnitude  \
# 0        2162117  162117 (1998 SD15)              19.140
# 1        2349507    349507 (2008 QY)              18.500
# 2        2455415    455415 (2003 GA)              21.450
# 3        3132126           (2002 PB)              20.630
# 4        3557844           (2011 DW)              22.700
# ...          ...                 ...                 ...
# 338194  54403809          (2023 VS4)              28.580
# 338195  54415298          (2023 XW5)              28.690
# 338196  54454871          (2024 KJ7)              21.919
# 338197  54456245           (2024 NE)              23.887
# 338198  54460573          (2024 NH3)              22.951
#
#         estimated_diameter_min  estimated_diameter_max orbiting_body  \
# 0                     0.394962                0.883161         Earth
# 1                     0.530341                1.185878         Earth
# 2                     0.136319                0.304818         Earth
# 3                     0.198863                0.444672         Earth
# 4                     0.076658                0.171412         Earth
# ...                        ...                     ...           ...
# 338194                0.005112                0.011430         Earth
# 338195                0.004859                0.010865         Earth
# 338196                0.109839                0.245607         Earth
# 338197                0.044377                0.099229         Earth
# 338198                0.068290                0.152700         Earth
#
#         relative_velocity  miss_distance  is_hazardous
# 0            71745.401048   5.814362e+07         False
# 1           109949.757148   5.580105e+07          True
# 2            24865.506798   6.720689e+07         False
# 3            78890.076805   3.039644e+07         False
# 4            56036.519484   6.311863e+07         False
# ...                   ...            ...           ...
# 338194       56646.985988   6.406548e+07         False
# 338195       21130.768947   2.948883e+07         False
# 338196       11832.041031   5.346078e+07         False
# 338197       56198.382733   5.184742e+06         False
# 338198       42060.357830   7.126682e+06         False
#
# [338199 rows x 9 columns]

# %%
# to get the basic info about the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 338199 entries, 0 to 338198
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   neo_id                  338199 non-null  int64
#  1   name                    338199 non-null  object
#  2   absolute_magnitude      338171 non-null  float64
#  3   estimated_diameter_min  338171 non-null  float64
#  4   estimated_diameter_max  338171 non-null  float64
#  5   orbiting_body           338199 non-null  object
#  6   relative_velocity       338199 non-null  float64
#  7   miss_distance           338199 non-null  float64
#  8   is_hazardous            338199 non-null  bool
# dtypes: bool(1), float64(5), int64(1), object(2)
# memory usage: 21.0+ MB

# %%
# to get the basic stats of dataset

df.describe()
# Out:
#              neo_id  absolute_magnitude  estimated_diameter_min  \
# count  3.381990e+05       338171.000000           338171.000000
# mean   1.759939e+07           22.932525                0.157812
# std    2.287225e+07            2.911216                0.313885
# min    2.000433e+06            9.250000                0.000511
# 25%    3.373980e+06           20.740000                0.025384
# 50%    3.742127e+06           22.800000                0.073207
# 75%    5.405374e+07           25.100000                0.189041
# max    5.446281e+07           33.580000               37.545248
#
#        estimated_diameter_max  relative_velocity  miss_distance
# count           338171.000000      338199.000000   3.381990e+05
# mean                 0.352878       51060.662908   4.153535e+07
# std                  0.701869       26399.238435   2.077399e+07
# min                  0.001143         203.346433   6.745533e+03
# 25%                  0.056760       30712.031471   2.494540e+07
# 50%                  0.163697       47560.465474   4.332674e+07
# 75%                  0.422708       66673.820614   5.933961e+07
# max                 83.953727      291781.106613   7.479865e+07

# %%
# to get the count of elements in is_hazardous column

e_count = df.is_hazardous.value_counts()
e_count
# Out:
# is_hazardous
# False    295037
# True      43162
# Name: count, dtype: int64

# %%
# to plot it in a chart

plt.title('Hazardous Effect')
e_count.plot(kind='bar',color='#FF6666')
plt.show()

# %%
# to check for null values

df.isnull().sum()/len(df)
# Out:
# neo_id                    0.000000
# name                      0.000000
# absolute_magnitude        0.000083
# estimated_diameter_min    0.000083
# estimated_diameter_max    0.000083
# orbiting_body             0.000000
# relative_velocity         0.000000
# miss_distance             0.000000
# is_hazardous              0.000000
# dtype: float64

# %%
# to drop the null values

len(df)
# Out:
# 338199

# %%
df = df.dropna()
df
# Out:
#           neo_id                name  absolute_magnitude  \
# 0        2162117  162117 (1998 SD15)              19.140
# 1        2349507    349507 (2008 QY)              18.500
# 2        2455415    455415 (2003 GA)              21.450
# 3        3132126           (2002 PB)              20.630
# 4        3557844           (2011 DW)              22.700
# ...          ...                 ...                 ...
# 338194  54403809          (2023 VS4)              28.580
# 338195  54415298          (2023 XW5)              28.690
# 338196  54454871          (2024 KJ7)              21.919
# 338197  54456245           (2024 NE)              23.887
# 338198  54460573          (2024 NH3)              22.951
#
#         estimated_diameter_min  estimated_diameter_max orbiting_body  \
# 0                     0.394962                0.883161         Earth
# 1                     0.530341                1.185878         Earth
# 2                     0.136319                0.304818         Earth
# 3                     0.198863                0.444672         Earth
# 4                     0.076658                0.171412         Earth
# ...                        ...                     ...           ...
# 338194                0.005112                0.011430         Earth
# 338195                0.004859                0.010865         Earth
# 338196                0.109839                0.245607         Earth
# 338197                0.044377                0.099229         Earth
# 338198                0.068290                0.152700         Earth
#
#         relative_velocity  miss_distance  is_hazardous
# 0            71745.401048   5.814362e+07         False
# 1           109949.757148   5.580105e+07          True
# 2            24865.506798   6.720689e+07         False
# 3            78890.076805   3.039644e+07         False
# 4            56036.519484   6.311863e+07         False
# ...                   ...            ...           ...
# 338194       56646.985988   6.406548e+07         False
# 338195       21130.768947   2.948883e+07         False
# 338196       11832.041031   5.346078e+07         False
# 338197       56198.382733   5.184742e+06         False
# 338198       42060.357830   7.126682e+06         False
#
# [338171 rows x 9 columns]

# %%
len(df)
# Out:
# 338171

# %%
df.isnull().sum()/len(df)
# Out:
# neo_id                    0.0
# name                      0.0
# absolute_magnitude        0.0
# estimated_diameter_min    0.0
# estimated_diameter_max    0.0
# orbiting_body             0.0
# relative_velocity         0.0
# miss_distance             0.0
# is_hazardous              0.0
# dtype: float64

# %%
df.describe()
# Out:
#              neo_id  absolute_magnitude  estimated_diameter_min  \
# count  3.381710e+05       338171.000000           338171.000000
# mean   1.760041e+07           22.932525                0.157812
# std    2.287276e+07            2.911216                0.313885
# min    2.000433e+06            9.250000                0.000511
# 25%    3.373980e+06           20.740000                0.025384
# 50%    3.742127e+06           22.800000                0.073207
# 75%    5.405374e+07           25.100000                0.189041
# max    5.446281e+07           33.580000               37.545248
#
#        estimated_diameter_max  relative_velocity  miss_distance
# count           338171.000000      338171.000000   3.381710e+05
# mean                 0.352878       51060.017994   4.153547e+07
# std                  0.701869       26399.922830   2.077411e+07
# min                  0.001143         203.346433   6.745533e+03
# 25%                  0.056760       30710.626399   2.494495e+07
# 50%                  0.163697       47557.046397   4.332724e+07
# 75%                  0.422708       66673.223798   5.933961e+07
# max                 83.953727      291781.106613   7.479865e+07

# %%
# to check the orbiting_body column is relevant or not

ob_count = df.orbiting_body.value_counts()
ob_count
# Out:
# orbiting_body
# Earth    338171
# Name: count, dtype: int64

# %%
ob_count.plot(kind='bar',color='skyblue')
plt.show()

# %%
# to drop the irrelevant columns

df.drop(['neo_id','name','orbiting_body'],axis=1,inplace=True)
# Out:
# C:\Users\Muhammed Thouyib TK\AppData\Local\Temp\ipykernel_16612\3480846115.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['neo_id','name','orbiting_body'],axis=1,inplace=True)

# %%
df
# Out:
#         absolute_magnitude  estimated_diameter_min  estimated_diameter_max  \
# 0                   19.140                0.394962                0.883161
# 1                   18.500                0.530341                1.185878
# 2                   21.450                0.136319                0.304818
# 3                   20.630                0.198863                0.444672
# 4                   22.700                0.076658                0.171412
# ...                    ...                     ...                     ...
# 338194              28.580                0.005112                0.011430
# 338195              28.690                0.004859                0.010865
# 338196              21.919                0.109839                0.245607
# 338197              23.887                0.044377                0.099229
# 338198              22.951                0.068290                0.152700
#
#         relative_velocity  miss_distance  is_hazardous
# 0            71745.401048   5.814362e+07         False
# 1           109949.757148   5.580105e+07          True
# 2            24865.506798   6.720689e+07         False
# 3            78890.076805   3.039644e+07         False
# 4            56036.519484   6.311863e+07         False
# ...                   ...            ...           ...
# 338194       56646.985988   6.406548e+07         False
# 338195       21130.768947   2.948883e+07         False
# 338196       11832.041031   5.346078e+07         False
# 338197       56198.382733   5.184742e+06         False
# 338198       42060.357830   7.126682e+06         False
#
# [338171 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 338171 entries, 0 to 338198
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   absolute_magnitude      338171 non-null  float64
#  1   estimated_diameter_min  338171 non-null  float64
#  2   estimated_diameter_max  338171 non-null  float64
#  3   relative_velocity       338171 non-null  float64
#  4   miss_distance           338171 non-null  float64
#  5   is_hazardous            338171 non-null  bool
# dtypes: bool(1), float64(5)
# memory usage: 15.8 MB

# %%
# to convert bool into integer by encoding

df['is_hazardous']=pd.get_dummies(df['is_hazardous'],dtype=int,drop_first=True)
# Out:
# C:\Users\Muhammed Thouyib TK\AppData\Local\Temp\ipykernel_16612\316309418.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_hazardous']=pd.get_dummies(df['is_hazardous'],dtype=int,drop_first=True)

# %%
df
# Out:
#         absolute_magnitude  estimated_diameter_min  estimated_diameter_max  \
# 0                   19.140                0.394962                0.883161
# 1                   18.500                0.530341                1.185878
# 2                   21.450                0.136319                0.304818
# 3                   20.630                0.198863                0.444672
# 4                   22.700                0.076658                0.171412
# ...                    ...                     ...                     ...
# 338194              28.580                0.005112                0.011430
# 338195              28.690                0.004859                0.010865
# 338196              21.919                0.109839                0.245607
# 338197              23.887                0.044377                0.099229
# 338198              22.951                0.068290                0.152700
#
#         relative_velocity  miss_distance  is_hazardous
# 0            71745.401048   5.814362e+07             0
# 1           109949.757148   5.580105e+07             1
# 2            24865.506798   6.720689e+07             0
# 3            78890.076805   3.039644e+07             0
# 4            56036.519484   6.311863e+07             0
# ...                   ...            ...           ...
# 338194       56646.985988   6.406548e+07             0
# 338195       21130.768947   2.948883e+07             0
# 338196       11832.041031   5.346078e+07             0
# 338197       56198.382733   5.184742e+06             0
# 338198       42060.357830   7.126682e+06             0
#
# [338171 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 338171 entries, 0 to 338198
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   absolute_magnitude      338171 non-null  float64
#  1   estimated_diameter_min  338171 non-null  float64
#  2   estimated_diameter_max  338171 non-null  float64
#  3   relative_velocity       338171 non-null  float64
#  4   miss_distance           338171 non-null  float64
#  5   is_hazardous            338171 non-null  int64
# dtypes: float64(5), int64(1)
# memory usage: 18.1 MB

# %%
# to get advanced stats 

import Dis_Stats as ds

for i in df.columns:
    print('||',i,'||')
    ds.calc_fo(df[i])
    print('='*50)
# Out:
# || absolute_magnitude ||
# Total  7755114.898
# Total Count 338171
# Mean 22.93252495926617
# Median 22.8
# Mode 24.4
# Minimum 9.25
# Maximum 33.58
# Range 24.33
# Variance 8.475155809286075
# Standard Deviation 2.9112120859336366
# Quartile 1 20.74
# Quartile 3 25.1
# Inter Quartile Range 4.360000000000003
# Lower Whisker 14.199999999999994
# Upper Whisker 31.640000000000008
# 0.08402015435846188
# -0.4755877693524617
# ==================================================
# || estimated_diameter_min ||
# Total  53367.4576312465
# Total Count 338171
# Mean 0.15781204666055487
# Median 0.0732073989
# Mode 0.0350392641
# Minimum 0.0005111578
# Maximum 37.5452479361
# Range 37.5447367783
# Variance 0.09852358843837723
# Standard Deviation 0.3138846737870093
# Quartile 1 0.0253837029
# Quartile 3 0.1890405519
# Inter Quartile Range 0.163656849
# Lower Whisker -0.2201015706
# Upper Whisker 0.43452582539999995
# 30.963126247146004
# 2664.5642097761993
# ==================================================
# || estimated_diameter_max ||
# Total  119333.2630495297
# Total Count 338171
# Mean 0.3528784640005491
# Median 0.1636967205
# Mode 0.0783501764
# Minimum 0.0011429835
# Maximum 83.9537266171
# Range 83.9525836336
# Variance 0.49261794218987953
# Standard Deviation 0.7018674676816696
# Quartile 1 0.0567596853
# Quartile 3 0.4227075246
# Inter Quartile Range 0.36594783929999997
# Lower Whisker -0.49216207365
# Upper Whisker 0.97162928355
# 30.963126247273113
# 2664.56420978674
# ==================================================
# || relative_velocity ||
# Total  17267017345.210663
# Total Count 338171
# Mean 51060.01799447813
# Median 47557.0463973955
# Mode 51964.0584077668
# Minimum 203.34643253
# Maximum 291781.1066131202
# Range 291577.7601805902
# Variance 696953864.4975755
# Standard Deviation 26399.883797046827
# Quartile 1 30710.62639880895
# Quartile 3 66673.2237976368
# Inter Quartile Range 35962.59739882786
# Lower Whisker -23233.269699432836
# Upper Whisker 120617.1198958786
# 0.8494634880530734
# 0.9675623188303257
# ==================================================
# || miss_distance ||
# Total  14046092596668.555
# Total Count 338171
# Mean 41535473.46362803
# Median 43327242.019174896
# Mode 573908.202837078
# Minimum 6745.532515957
# Maximum 74798651.4521972
# Range 74791905.91968124
# Variance 431562566565299.56
# Standard Deviation 20774084.012665868
# Quartile 1 24944951.86011888
# Quartile 3 59339605.219975345
# Inter Quartile Range 34394653.359856464
# Lower Whisker -26647028.17966582
# Upper Whisker 110931585.25976005
# -0.23505259022004793
# -1.0567229932223257
# ==================================================
# || is_hazardous ||
# Total  43162
# Total Count 338171
# Mean 0.12763365279695776
# Median 0.0
# Mode 0
# Minimum 0
# Maximum 1
# Range 1
# Variance 0.11134330347066339
# Standard Deviation 0.33368144010517486
# Quartile 1 0.0
# Quartile 3 0.0
# Inter Quartile Range 0.0
# Lower Whisker 0.0
# Upper Whisker 0.0
# 2.2318672988565034
# 2.9812316397050243
# ==================================================

# %%
# to create boxplot for checking outliers 

for i in df.columns:
    print(i)
    sns.boxplot(df[i])
    plt.show()
# Out:
# absolute_magnitude
# estimated_diameter_min
# estimated_diameter_max
# relative_velocity
# miss_distance
# is_hazardous

# %%
# to create distribution plot

for i in df.drop('is_hazardous',axis=1).columns:
    print(i)
    sns.displot(data=df,x=i,hue='is_hazardous')
    plt.show()
# Out:
# absolute_magnitude
# estimated_diameter_min
# estimated_diameter_max
# relative_velocity
# miss_distance

# %%
# to create violinplot

for i in df.drop('is_hazardous',axis=1).columns:
    print(i)
    sns.violinplot(data=df,x=i,hue='is_hazardous')
    plt.show()
# Out:
# absolute_magnitude
# estimated_diameter_min
# estimated_diameter_max
# relative_velocity
# miss_distance

# %%
# to create pairplot

sns.heatmap(df.corr(),annot=True,vmin=-1,vmax=1,cmap='coolwarm')
# Out:
# <Axes: >

# %%
# the estimated_diameter_min & estimated_diameter_max are perfectly correlated , so drop any one of them

df.drop('estimated_diameter_min',axis=1,inplace=True)
# Out:
# C:\Users\Muhammed Thouyib TK\AppData\Local\Temp\ipykernel_16612\4081657976.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('estimated_diameter_min',axis=1,inplace=True)

# %%
df
# Out:
#         absolute_magnitude  estimated_diameter_max  relative_velocity  \
# 0                   19.140                0.883161       71745.401048
# 1                   18.500                1.185878      109949.757148
# 2                   21.450                0.304818       24865.506798
# 3                   20.630                0.444672       78890.076805
# 4                   22.700                0.171412       56036.519484
# ...                    ...                     ...                ...
# 338194              28.580                0.011430       56646.985988
# 338195              28.690                0.010865       21130.768947
# 338196              21.919                0.245607       11832.041031
# 338197              23.887                0.099229       56198.382733
# 338198              22.951                0.152700       42060.357830
#
#         miss_distance  is_hazardous
# 0        5.814362e+07             0
# 1        5.580105e+07             1
# 2        6.720689e+07             0
# 3        3.039644e+07             0
# 4        6.311863e+07             0
# ...               ...           ...
# 338194   6.406548e+07             0
# 338195   2.948883e+07             0
# 338196   5.346078e+07             0
# 338197   5.184742e+06             0
# 338198   7.126682e+06             0
#
# [338171 rows x 5 columns]

# %%
# to create a function that remove outliers

def remove_outliers(data,column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - IQR*1.5
    upper = Q3 + IQR*1.5
    before = len(data)
    data = data[(data[column]>=lower) & (data[column]<=upper)]
    Updated = before - len(data)
    print('Removed rows :',Updated)

# %%
for i in df.drop('is_hazardous',axis=1).columns:
    remove_outliers(df,i)
# Out:
# Removed rows : 389
# Removed rows : 26166
# Removed rows : 5448
# Removed rows : 0

# %%
# to split the dataset

x = df.drop('is_hazardous',axis=1)
y = df['is_hazardous']

# %%
x
# Out:
#         absolute_magnitude  estimated_diameter_max  relative_velocity  \
# 0                   19.140                0.883161       71745.401048
# 1                   18.500                1.185878      109949.757148
# 2                   21.450                0.304818       24865.506798
# 3                   20.630                0.444672       78890.076805
# 4                   22.700                0.171412       56036.519484
# ...                    ...                     ...                ...
# 338194              28.580                0.011430       56646.985988
# 338195              28.690                0.010865       21130.768947
# 338196              21.919                0.245607       11832.041031
# 338197              23.887                0.099229       56198.382733
# 338198              22.951                0.152700       42060.357830
#
#         miss_distance
# 0        5.814362e+07
# 1        5.580105e+07
# 2        6.720689e+07
# 3        3.039644e+07
# 4        6.311863e+07
# ...               ...
# 338194   6.406548e+07
# 338195   2.948883e+07
# 338196   5.346078e+07
# 338197   5.184742e+06
# 338198   7.126682e+06
#
# [338171 rows x 4 columns]

# %%
y
# Out:
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 338194    0
# 338195    0
# 338196    0
# 338197    0
# 338198    0
# Name: is_hazardous, Length: 338171, dtype: int64

# %%
# to split the data into training & testing (CV)

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#         absolute_magnitude  estimated_diameter_max  relative_velocity  \
# 108946               18.70                1.081534      128822.404674
# 25572                22.75                0.167510       38706.719006
# 307001               26.86                0.025237       29243.381534
# 11765                22.21                0.214803       74013.386113
# 207306               25.50                0.047211       38289.320174
# ...                    ...                     ...                ...
# 119883               22.23                0.212833       64366.740472
# 259197               27.10                0.022596       49230.951416
# 131936               21.48                0.300635       22901.361812
# 146872               27.50                0.018795       21820.930366
# 121962               27.00                0.023661       59713.345952
#
#         miss_distance
# 108946   6.220195e+07
# 25572    1.733822e+07
# 307001   4.811080e+07
# 11765    7.085015e+07
# 207306   4.391704e+07
# ...               ...
# 119883   4.174997e+07
# 259197   5.904041e+07
# 131936   6.784025e+07
# 146872   5.580897e+07
# 121962   6.855200e+07
#
# [270536 rows x 4 columns]

# %%
x_test
# Out:
#         absolute_magnitude  estimated_diameter_max  relative_velocity  \
# 313083               26.00                0.037501       20674.605109
# 229327               26.40                0.031192       83322.237180
# 147689               25.31                0.051528       16497.682909
# 162245               31.46                0.003034       64667.069702
# 115618               23.65                0.110673       15618.336289
# ...                    ...                     ...                ...
# 323868               24.11                0.089545       23160.141352
# 2952                 22.80                0.163697       49005.937960
# 316310               25.30                0.051765       21254.033664
# 305942               25.70                0.043057       26224.026164
# 138162               18.37                1.259041       90407.768005
#
#         miss_distance
# 313083   8.875338e+06
# 229327   5.784726e+07
# 147689   2.584028e+07
# 162245   5.028880e+06
# 115618   4.815892e+07
# ...               ...
# 323868   9.472906e+06
# 2952     7.450169e+07
# 316310   3.026582e+07
# 305942   3.183005e+06
# 138162   3.637371e+07
#
# [67635 rows x 4 columns]

# %%
y_train
# Out:
# 108946    1
# 25572     0
# 307001    0
# 11765     0
# 207306    0
#          ..
# 119883    0
# 259197    0
# 131936    1
# 146872    0
# 121962    0
# Name: is_hazardous, Length: 270536, dtype: int64

# %%
y_test
# Out:
# 313083    0
# 229327    0
# 147689    0
# 162245    0
# 115618    0
#          ..
# 323868    0
# 2952      0
# 316310    0
# 305942    0
# 138162    0
# Name: is_hazardous, Length: 67635, dtype: int64

# %%
# to check the training data is balanced

y_train.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='is_hazardous'>

# %%
# to generate some fake data based on the input data we have

from imblearn import over_sampling

# synthetic minority over-sampling technique (SMOTE)

se = over_sampling.SMOTE()

# %%
x_train_balanced,y_train_balanced = se.fit_resample(x_train,y_train)
# Out:
# C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(
# C:\Users\Muhammed Thouyib TK\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\_tags.py:354: FutureWarning: The SMOTE or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(

# %%
y_train.value_counts()
# Out:
# is_hazardous
# 0    235921
# 1     34615
# Name: count, dtype: int64

# %%
y_train_balanced.value_counts()
# Out:
# is_hazardous
# 1    235921
# 0    235921
# Name: count, dtype: int64

# %%
x_train_balanced
# Out:
#         absolute_magnitude  estimated_diameter_max  relative_velocity  \
# 0                18.700000                1.081534      128822.404674
# 1                22.750000                0.167510       38706.719006
# 2                26.860000                0.025237       29243.381534
# 3                22.210000                0.214803       74013.386113
# 4                25.500000                0.047211       38289.320174
# ...                    ...                     ...                ...
# 471837           20.376006                0.524388       37532.859854
# 471838           19.217432                1.229366       42264.712582
# 471839           21.440918                0.307042       77251.340537
# 471840           21.190017                0.345335       34215.538743
# 471841           20.372632                0.520383       77741.687816
#
#         miss_distance
# 0        6.220195e+07
# 1        1.733822e+07
# 2        4.811080e+07
# 3        7.085015e+07
# 4        4.391704e+07
# ...               ...
# 471837   1.174546e+07
# 471838   1.322925e+07
# 471839   4.149330e+07
# 471840   2.824636e+07
# 471841   9.649662e+06
#
# [471842 rows x 4 columns]

# %%
x_test
# Out:
#         absolute_magnitude  estimated_diameter_max  relative_velocity  \
# 313083               26.00                0.037501       20674.605109
# 229327               26.40                0.031192       83322.237180
# 147689               25.31                0.051528       16497.682909
# 162245               31.46                0.003034       64667.069702
# 115618               23.65                0.110673       15618.336289
# ...                    ...                     ...                ...
# 323868               24.11                0.089545       23160.141352
# 2952                 22.80                0.163697       49005.937960
# 316310               25.30                0.051765       21254.033664
# 305942               25.70                0.043057       26224.026164
# 138162               18.37                1.259041       90407.768005
#
#         miss_distance
# 313083   8.875338e+06
# 229327   5.784726e+07
# 147689   2.584028e+07
# 162245   5.028880e+06
# 115618   4.815892e+07
# ...               ...
# 323868   9.472906e+06
# 2952     7.450169e+07
# 316310   3.026582e+07
# 305942   3.183005e+06
# 138162   3.637371e+07
#
# [67635 rows x 4 columns]

# %%
# Logistic Regression

from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

# %%
lr.fit(x_train_balanced,y_train_balanced)
# Out:
# LogisticRegression()

# %%
y_pred_test = lr.predict(x_test)
y_pred_test
# Out:
# array([1, 1, 0, ..., 0, 1, 1])

# %%
# to get the classification report

from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.50      0.65     59088
#            1       0.16      0.68      0.27      8547
#
#     accuracy                           0.52     67635
#    macro avg       0.54      0.59      0.46     67635
# weighted avg       0.82      0.52      0.60     67635

# %%
# Random Forest

from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(x_train_balanced,y_train_balanced)
# Out:
# RandomForestClassifier()

# %%
rfc_pred_test = rf.predict(x_test)

# %%
print(classification_report(y_test,rfc_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95     59088
#            1       0.64      0.67      0.66      8547
#
#     accuracy                           0.91     67635
#    macro avg       0.80      0.81      0.80     67635
# weighted avg       0.91      0.91      0.91     67635

# %%
from sklearn.metrics import roc_auc_score

print("ROC-AUC Score:", roc_auc_score(y_test, rf.predict_proba(x_test)[:, 1]))
# Out:
# ROC-AUC Score: 0.9459154494440847
